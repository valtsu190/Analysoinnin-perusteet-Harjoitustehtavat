# %%
# Tehtävä 1

# %%
number1 = 6; number2 = 5;

# %%
if (number1 == number2):
    print("number 1 and number 2 are equal")

# %%
if (number1 > number2):
    print("number 1 is greater than number 2")
# Out:
# number 1 is greater than number 2

# %%
if (number1 >= number2):
    print("number 1 is greater or equal to number 2")
# Out:
# number 1 is greater or equal to number 2

# %%
if (number1 != number2):
    print("number 1 is not equal to number 2")
# Out:
# number 1 is not equal to number 2

# %%
# Tehtävä 2

# %%
number1 = 9; number2 = 19; number3 = 9

# %%
if (number1 == number2 and number2 == number3):
    print("Numbers are equal")

# %%
if (number1 == number2 or number2 == number3):
    print("Numbers 1 and 2 or 2 and 3 are equal")

# %%
if (number1 > number2 and number1 > number3):
    print("Number 1 is greater than 2 and 3")

# %%
if (number1 > number2):
    print("Number 1 is greater than number 2")
elif (number2 > number3):
    print("Number 2 is greater than number 3 ")
# Out:
# Number 2 is greater than number 3

# %%
if (number1 == number2):
    print("Number 1 and 2 are equal")
elif (number1 == number3):
    print("Number 1 and 3 are equal")
# Out:
# Number 1 and 3 are equal

# %%
# Tehtävä 3

# %%
name1 = "hi"; name2 = "hello"; name3 = "hi"

# %%
if(name1 == name2):
    print("Strings are equal")

# %%
if(name1 != name2):
    print("Strings are not equal")
# Out:
# Strings are not equal

# %%
if(name1 == name2):
    print("Strings 1 and 2 are equal")
elif(name1==name3):
    print("String 1 and 3 are equal")
# Out:
# String 1 and 3 are equal
