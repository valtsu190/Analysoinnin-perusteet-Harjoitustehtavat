# %%
furniture = ["table", "chair", "shelf", "sofa"]
print(furniture)
import random
# Out:
# ['table', 'chair', 'shelf', 'sofa']

# %%
print(furniture[0:2])
# Out:
# ['table', 'chair']

# %%
for i in furniture:
    if (i =="sofa"):
        print(i)
# Out:
# sofa

# %%
num1 = random.randint(1, 6)
num2 = random.randint(1, 6)
num3 = random.randint(1, 6)
num4 = random.randint(1, 6)
num5 = random.randint(1, 6)

thrownDiceNumbers = [num1, num2, num3, num4, num5]

for number in thrownDiceNumbers:
    print(number)
# Out:
# 4
# 4
# 1
# 2
# 1

# %%
summa = 0

for number in thrownDiceNumbers:
    summa = summa + number

print(summa)
# Out:
# 28

# %%
thrownDiceNumbers.sort()
print(thrownDiceNumbers[4])
# Out:
# 4
